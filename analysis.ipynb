# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('immigration_data.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    CO2 Country of birth/nationality  VAR  \
# 0  AFG                  Afghanistan  B11
# 1  AFG                  Afghanistan  B11
# 2  AFG                  Afghanistan  B11
# 3  AFG                  Afghanistan  B11
# 4  AFG                  Afghanistan  B11
#
#                                        Variable  GEN Gender  COU    Country  \
# 0  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 1  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 2  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 3  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
# 4  Inflows of foreign population by nationality  TOT  Total  AUS  Australia
#
#     YEA  Year   Value Flag Codes Flags
# 0  2000  2000   887.0        NaN   NaN
# 1  2001  2001   456.0        NaN   NaN
# 2  2002  2002   660.0        NaN   NaN
# 3  2003  2003  1015.0        NaN   NaN
# 4  2004  2004  1340.0        NaN   NaN

# %%
df_inflow = df[df.Variable=='Inflows of foreign population by nationality']

# %%
df_inflow.describe(include='all')
# Out:
#           CO2 Country of birth/nationality    VAR  \
# count   88957                        88957  88957
# unique    210                          210      1
# top       TOT                        Total    B11
# freq      591                          591  88957
# mean      NaN                          NaN    NaN
# std       NaN                          NaN    NaN
# min       NaN                          NaN    NaN
# 25%       NaN                          NaN    NaN
# 50%       NaN                          NaN    NaN
# 75%       NaN                          NaN    NaN
# max       NaN                          NaN    NaN
#
#                                             Variable    GEN Gender    COU  \
# count                                          88957  88957  88957  88957
# unique                                             1      1      1     35
# top     Inflows of foreign population by nationality    TOT  Total    AUS
# ...

# %%
plt.scatter(df_inflow['Year'], df_inflow['Value'])

# %%
df_in_flow_china = df_inflow[df_inflow['CO2']=='CHN']

# %%
plt.plot(df_in_flow_china.Year, df_in_flow_china.Value)

# %%
df_in_flow_china.head(30)
# Out:
#        CO2 Country of birth/nationality  VAR  \
# 39708  CHN                        China  B11
# 39709  CHN                        China  B11
# 39710  CHN                        China  B11
# 39711  CHN                        China  B11
# 39712  CHN                        China  B11
# 39713  CHN                        China  B11
# 39714  CHN                        China  B11
# 39715  CHN                        China  B11
# 39716  CHN                        China  B11
# 39717  CHN                        China  B11
# 39718  CHN                        China  B11
# 39719  CHN                        China  B11
# 39720  CHN                        China  B11
# 39721  CHN                        China  B11
# 39722  CHN                        China  B11
# 39723  CHN                        China  B11
# 39724  CHN                        China  B11
# 39725  CHN                        China  B11
# 39726  CHN                        China  B11
# 39742  CHN                        China  B11
# ...

# %%
df_in_flow_china['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Hungary', 'Iceland',
#        'Italy', 'Japan', 'Korea', 'Luxembourg', 'Mexico', 'Netherlands',
#        'New Zealand', 'Norway', 'Poland', 'Portugal', 'Slovak Republic',
#        'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Kingdom',
#        'United States', 'Chile', 'Estonia', 'Slovenia', 'Latvia'],
#       dtype=object)

# %%
df_in_flow_china[['Value', 'Country']].groupby('Country').sum()
# Out:
#                      Value
# Country
# Australia         389446.0
# Austria            28311.0
# Belgium            25560.0
# Canada            574050.0
# Chile              14772.0
# Czech Republic      9616.0
# Denmark            18488.0
# Estonia              519.0
# Finland            11133.0
# France             83427.0
# Germany           328094.0
# Hungary            27097.0
# Iceland             1577.0
# Italy             256298.0
# Japan            1852460.0
# Korea            2343203.0
# Latvia               190.0
# Luxembourg          3540.0
# Mexico             21228.0
# Netherlands        75043.0
# New Zealand       144968.0
# Norway             13151.0
# Poland             31603.0
# Portugal           30664.0
# Slovak Republic     1050.0
# Slovenia            1775.0
# Spain             211945.0
# Sweden             37751.0
# Switzerland        21826.0
# Turkey             14258.0
# United Kingdom    570039.0
# United States    1252845.0

# %%
# need to get the meaning of the variables

# %%
df.columns = ['CO2', 'Country of birth/nationality', 'VAR', 'Variable', 'GEN',
       'Gender', 'COU', 'Country', 'YEA', 'Year', 'Value', 'Flag Codes',
       'Flags']
# Out:
# Index(['CO2', 'Country of birth/nationality', 'VAR', 'Variable', 'GEN',
#        'Gender', 'COU', 'Country', 'YEA', 'Year', 'Value', 'Flag Codes',
#        'Flags'],
#       dtype='object')

# %%
df.drop(['Flag Codes',
       'Flags', 'YEA', 'GEN', 'VAR'], axis = 1, inplace=True)

# %%
df.columns = ['Country_from', 'Nationality', 'Variable', 'Gender', 'Country_to',
       'Country', 'Year', 'Value']

# %%
df.head()
# Out:
#   Country_from  Nationality                                      Variable  \
# 0          AFG  Afghanistan  Inflows of foreign population by nationality
# 1          AFG  Afghanistan  Inflows of foreign population by nationality
# 2          AFG  Afghanistan  Inflows of foreign population by nationality
# 3          AFG  Afghanistan  Inflows of foreign population by nationality
# 4          AFG  Afghanistan  Inflows of foreign population by nationality
#
#   Gender Country_to    Country  Year   Value
# 0  Total        AUS  Australia  2000   887.0
# 1  Total        AUS  Australia  2001   456.0
# 2  Total        AUS  Australia  2002   660.0
# 3  Total        AUS  Australia  2003  1015.0
# 4  Total        AUS  Australia  2004  1340.0

# %%
df_china_to_us = df[(df.Nationality=='China')&(df.Country=="United States") & (df.Variable=='Inflows of foreign population by nationality')]

# %%
df_china_to_us["Variable"].unique()
# Out:
# array(['Inflows of foreign population by nationality'], dtype=object)

# %%
df_china_to_us
# Out:
#       Country_from Nationality                                      Variable  \
# 40512          CHN       China  Inflows of foreign population by nationality
# 40513          CHN       China  Inflows of foreign population by nationality
# 40514          CHN       China  Inflows of foreign population by nationality
# 40515          CHN       China  Inflows of foreign population by nationality
# 40516          CHN       China  Inflows of foreign population by nationality
# 40517          CHN       China  Inflows of foreign population by nationality
# 40518          CHN       China  Inflows of foreign population by nationality
# 40519          CHN       China  Inflows of foreign population by nationality
# 40520          CHN       China  Inflows of foreign population by nationality
# 40521          CHN       China  Inflows of foreign population by nationality
# 40522          CHN       China  Inflows of foreign population by nationality
# ...

# %%
df_china_to_us.set_index('Year')
# Out:
#      Country_from Nationality                                      Variable  \
# Year
# 2000          CHN       China  Inflows of foreign population by nationality
# 2001          CHN       China  Inflows of foreign population by nationality
# 2002          CHN       China  Inflows of foreign population by nationality
# 2003          CHN       China  Inflows of foreign population by nationality
# 2004          CHN       China  Inflows of foreign population by nationality
# 2005          CHN       China  Inflows of foreign population by nationality
# 2006          CHN       China  Inflows of foreign population by nationality
# 2007          CHN       China  Inflows of foreign population by nationality
# 2008          CHN       China  Inflows of foreign population by nationality
# 2009          CHN       China  Inflows of foreign population by nationality
# 2010          CHN       China  Inflows of foreign population by nationality
# ...

# %%
df_china_to_us.index
# Out:
# Int64Index([40512, 40513, 40514, 40515, 40516, 40517, 40518, 40519, 40520,
#             40521, 40522, 40523, 40524, 40525, 40526, 40527, 40528, 40529],
#            dtype='int64')

# %%
df_china_to_us.index = range(2000, 2018)
df_china_to_us.index = df_china_to_us.index.map(str)

# %%
plt.figure(figsize=(10,10))
plt.plot(df_china_to_us.index, df_china_to_us['Value'])

# %%
df_china_to_us['Value'].sum()
# Out:
# 1252845.0

# %%
df_us_to_china = df[(df.Nationality=='United States')&(df.Country=="China")]

# %%
df_us_to_china
# Out:
# Empty DataFrame
# Columns: [Country_from, Nationality, Variable, Gender, Country_to, Country, Year, Value]
# Index: []

# %%
df[(df.Country=="United States")]['Value'].sum()
# Out:
# 2139794993.0

# %%
df[(df.Nationality=="United States")]['Value'].sum()
# Out:
# 28306606.0

# %%
df[(df.Country=="China")]['Value'].sum()
# Out:
# 0.0

# %%
df[(df.Nationality=="China")]['Value'].sum()
# Out:
# 100042099.0

# %%
df[(df.Nationality=="China")]['Value'].mean()
# Out:
# 33616.29670698925
